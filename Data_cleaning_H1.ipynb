# %% [markdown]
# <h1>#import data using pandas</h1>

# %%
import pandas as pd
filename='C:/Users/User/Desktop/DATA FYP/H/H1.csv'
review_h=pd.read_csv(filename,sep=',')
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       The location of this hotel is very good.
# 1    7.1                                Great location.
# 2    9.2                       Nice but could be better
# 3    6.7       The hotel is clean & the view is amazing
# 4     10   Excellent location with very friendly staff.
#
#                                               review
# 0   Everything was good. If we have to come up wi...
# 1   Old furniture. Breakfast was not fulfilling f...
# 2   The maintenance of the place should be a bit ...
# 3   I stayed in twin bedroom. It suits for couple...
# 4   The lifts are a little confusing at first and...

# %% [markdown]
# <h1> Data Cleaning</h1>

# %% [markdown]
# <h1>transform the text into lowercase</h1>

# %%
review_h=review_h.apply(lambda x: x.astype(str).str.lower())

# %%
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       the location of this hotel is very good.
# 1    7.1                                great location.
# 2    9.2                       nice but could be better
# 3    6.7       the hotel is clean & the view is amazing
# 4     10   excellent location with very friendly staff.
#
#                                               review
# 0   everything was good. if we have to come up wi...
# 1   old furniture. breakfast was not fulfilling f...
# 2   the maintenance of the place should be a bit ...
# 3   i stayed in twin bedroom. it suits for couple...
# 4   the lifts are a little confusing at first and...

# %% [markdown]
# <h1>#combine title and review</h1>

# %%
review_h['review_com'] = review_h['title'].str.cat(review_h['review'],sep=" ")
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       the location of this hotel is very good.
# 1    7.1                                great location.
# 2    9.2                       nice but could be better
# 3    6.7       the hotel is clean & the view is amazing
# 4     10   excellent location with very friendly staff.
#
#                                               review  \
# 0   everything was good. if we have to come up wi...
# 1   old furniture. breakfast was not fulfilling f...
# 2   the maintenance of the place should be a bit ...
# 3   i stayed in twin bedroom. it suits for couple...
# 4   the lifts are a little confusing at first and...
#
#                                           review_com
# 0   the location of this hotel is very good.  eve...
# 1   great location.  old furniture. breakfast was...
# 2   nice but could be better  the maintenance of ...
# 3   the hotel is clean & the view is amazing  i s...
# ...

# %% [markdown]
# review_h['review_com'] = review_h['review']
# review_h.head()

# %% [markdown]
# size of data

# %%
review_h.shape
# Out:
# (4503, 4)

# %% [markdown]
# <h1>remove duplicate review</h1>

# %%
review_h.drop_duplicates()
# Out:
#          rating                                              title  \
# 0           8.3           the location of this hotel is very good.
# 1           7.1                                    great location.
# 2           9.2                           nice but could be better
# 3           6.7           the hotel is clean & the view is amazing
# 4            10       excellent location with very friendly staff.
# 5           8.3                              need to improve more
# 6           9.2                                 location  service
# 7            10           wonderful days at the grand hyatt hotel!
# 8            10                                 overall great stay
# 9            10               the wonderful staff   location  view
# 10          7.5                              enjoyed it very much!
# 11           10                                    awesome time :)
# 12          9.2                      great sauna and steam room
# ...

# %% [markdown]
# <h1>#remove symbol</h1>

# %%
review_h['review_com']=review_h['review_com'].str.replace("."," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("-"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("?"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace(":","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace(";"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("!","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("œ","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace(")"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("("," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com'] = review_h['review_com'].str.replace('"', ' ')
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("'"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean & the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("&"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("/"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("%"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("@"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("+"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("~"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("Ã¢â‚¬â„¢s","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("â€™","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("â€","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("*","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("ï¼œ"," ")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("\x9d","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("=","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("#","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("â€¹","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("â¥","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace(",","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("â€","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("Ã©","e")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("’","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("ðŸ˜Š","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("<","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("‘","")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace("Ã§","a")
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('^\d+\s+', '')
review_h['review_com'].head()
# Out:
# 0     the location of this hotel is very good   eve...
# 1     great location   old furniture  breakfast was...
# 2     nice but could be better  the maintenance of ...
# 3     the hotel is clean   the view is amazing  i s...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace(r'\b(\w{1,3})\b', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('^^', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('…', ' ')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('🙂', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😃', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('👌🏻', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('\\', ' ')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😊', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('👍🏼', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('é', 'e')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('{', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('—', ' ')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('˜€˜€˜€', ' ')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('\u200f', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('ç', 'c')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('>', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('$', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('–', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('‰', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('“', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('´', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('[', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace(']', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('}', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('£', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('`', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😋', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('👍', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😗', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😀', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('ž\x8f', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😚😚😚😚😚', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😉😉😉😉😉😉😇😙😙😙😙😙', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😍', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😋', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😘😘😘😘😘', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('👎🏻', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('🤓', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('💖', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('\x81‰', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('😁', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('،', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¦', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('\x8f', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('|', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('”', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('©', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('\x8d\x8f', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('ã©', 'e')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¸\x8f', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('â', 'e')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('»', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¢', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¨', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('ã', 'e')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('™\x8f\x8f', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('«', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('™¡', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('tðÿ\x8d\x8d\x8d', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('ï¼\x81', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('®', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('˜‰', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¿¿¿¿¿¿', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('‡\x8f€€', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('‚¬', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¤', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('^^', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('†', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('™\x8f', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('ðÿ', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('‹', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('\x8d', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('˜‡˜™˜™˜™˜™˜™', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('\x81', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('ž', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¸¸¸¸¸¸¸¸¸¸', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¸¸¸¸¸', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¥', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¶', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¯', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('¸', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('•', '')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('ï¼', ' ')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %%
review_h['review_com']=review_h['review_com'].str.replace('e\xad\x90\xad\x90\xad\x90\xad\x90\xad\x90\xad\x90\xad\x90', ' ')
review_h['review_com'].head()
# Out:
# 0      location  this hotel  very good   everything...
# 1     great location    furniture  breakfast   fulf...
# 2     nice  could  better   maintenance   place sho...
# 3      hotel  clean    view  amazing   stayed  twin...
# 4     excellent location with very friendly staff  ...
# Name: review_com, dtype: object

# %% [markdown]
# review_h.to_csv("data_clean1.csv", index=False, dencoding='utf8')

# %% [markdown]
# <h1>#import nltk from nltk.tokenize import word_tokenize</h1>

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
review_h['tokenized_word'] = review_h.apply(lambda row: nltk.word_tokenize(row['review_com']), axis=1)

# %%
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       the location of this hotel is very good.
# 1    7.1                                great location.
# 2    9.2                       nice but could be better
# 3    6.7       the hotel is clean & the view is amazing
# 4     10   excellent location with very friendly staff.
#
#                                               review  \
# 0   everything was good. if we have to come up wi...
# 1   old furniture. breakfast was not fulfilling f...
# 2   the maintenance of the place should be a bit ...
# 3   i stayed in twin bedroom. it suits for couple...
# 4   the lifts are a little confusing at first and...
#
#                                           review_com  \
# 0    location  this hotel  very good   everything...
# 1   great location    furniture  breakfast   fulf...
# 2   nice  could  better   maintenance   place sho...
# 3    hotel  clean    view  amazing   stayed  twin...
# ...

# %% [markdown]
# <h1>remove stopwords</h1>

# %%
from nltk.corpus import stopwords

# %%
stops = stopwords.words("English")
review_h['rev_stop_tree']=review_h['tokenized_word'].apply(lambda x: [item for item in x if item not in stops])
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       the location of this hotel is very good.
# 1    7.1                                great location.
# 2    9.2                       nice but could be better
# 3    6.7       the hotel is clean & the view is amazing
# 4     10   excellent location with very friendly staff.
#
#                                               review  \
# 0   everything was good. if we have to come up wi...
# 1   old furniture. breakfast was not fulfilling f...
# 2   the maintenance of the place should be a bit ...
# 3   i stayed in twin bedroom. it suits for couple...
# 4   the lifts are a little confusing at first and...
#
#                                           review_com  \
# 0    location  this hotel  very good   everything...
# 1   great location    furniture  breakfast   fulf...
# 2   nice  could  better   maintenance   place sho...
# 3    hotel  clean    view  amazing   stayed  twin...
# ...

# %% [markdown]
# <h1> Stemming<h1>

# %%
porter = nltk.PorterStemmer()
review_h['rev_porter'] = review_h['rev_stop_tree'].apply(lambda x: [porter.stem(y) for y in x])

# %%
lancaster = nltk.LancasterStemmer()
review_h['rev_lan'] = review_h['rev_stop_tree'].apply(lambda x: [lancaster.stem(y) for y in x])

# %%
snow = nltk.SnowballStemmer('english')
review_h['rev_snow'] = review_h['rev_stop_tree'].apply(lambda x: [snow.stem(y) for y in x])

# %%
import nltk
from nltk.stem import WordNetLemmatizer 

# Init the Wordnet Lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
review_h['lemma'] = review_h['rev_stop_tree'].apply(lambda x: [lemmatizer.lemmatize(y) for y in x])

# %%
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       the location of this hotel is very good.
# 1    7.1                                great location.
# 2    9.2                       nice but could be better
# 3    6.7       the hotel is clean & the view is amazing
# 4     10   excellent location with very friendly staff.
#
#                                               review  \
# 0   everything was good. if we have to come up wi...
# 1   old furniture. breakfast was not fulfilling f...
# 2   the maintenance of the place should be a bit ...
# 3   i stayed in twin bedroom. it suits for couple...
# 4   the lifts are a little confusing at first and...
#
#                                           review_com  \
# 0    location  this hotel  very good   everything...
# 1   great location    furniture  breakfast   fulf...
# 2   nice  could  better   maintenance   place sho...
# 3    hotel  clean    view  amazing   stayed  twin...
# ...

# %%
review_h['lemma2']=[" ".join(review_h) for review_h in review_h['lemma'].values]
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       the location of this hotel is very good.
# 1    7.1                                great location.
# 2    9.2                       nice but could be better
# 3    6.7       the hotel is clean & the view is amazing
# 4     10   excellent location with very friendly staff.
#
#                                               review  \
# 0   everything was good. if we have to come up wi...
# 1   old furniture. breakfast was not fulfilling f...
# 2   the maintenance of the place should be a bit ...
# 3   i stayed in twin bedroom. it suits for couple...
# 4   the lifts are a little confusing at first and...
#
#                                           review_com  \
# 0    location  this hotel  very good   everything...
# 1   great location    furniture  breakfast   fulf...
# 2   nice  could  better   maintenance   place sho...
# 3    hotel  clean    view  amazing   stayed  twin...
# ...

# %%
review_h.to_csv("data_clean.csv", index=False, encoding='utf8')

# %%
compare_stem=review_h[['rev_porter','rev_lan','rev_snow','lemma']]
compare_stem.head()
# Out:
#                                           rev_porter  \
# 0  [locat, hotel, good, everyth, good, come, some...
# 1  [great, locat, furnitur, breakfast, fulfil, di...
# 2  [nice, could, better, mainten, place, stringen...
# 3  [hotel, clean, view, amaz, stay, twin, bedroom...
# 4  [excel, locat, friendli, staff, lift, littl, c...
#
#                                              rev_lan  \
# 0  [loc, hotel, good, everyth, good, com, someth,...
# 1  [gre, loc, furnit, breakfast, fulfil, diff, ta...
# 2  [nic, could, bet, maint, plac, stringent, fixt...
# 3  [hotel, cle, view, amaz, stay, twin, bedroom, ...
# 4  [excel, loc, friend, staff, lift, littl, confu...
#
#                                             rev_snow  \
# 0  [locat, hotel, good, everyth, good, come, some...
# 1  [great, locat, furnitur, breakfast, fulfil, di...
# 2  [nice, could, better, mainten, place, stringen...
# 3  [hotel, clean, view, amaz, stay, twin, bedroom...
# ...

# %%
stem_porter=review_h['rev_porter']
from nltk.probability import FreqDist
newlist5=[]
fd_words = FreqDist(newlist5)
for x in stem_porter:
    newlist5+=x

# %%
stem_lan=review_h['rev_lan']
from nltk.probability import FreqDist
newlist6=[]
fd_words = FreqDist(newlist6)
for x in stem_lan:
    newlist6+=x

# %%
stem_snow=review_h['rev_snow']
from nltk.probability import FreqDist
newlist7=[]
fd_words = FreqDist(newlist7)
for x in stem_snow:
    newlist7+=x

# %%
stem_lemma=review_h['lemma']
from nltk.probability import FreqDist
newlist8=[]
fd_words = FreqDist(newlist8)
for x in stem_lemma:
    newlist8+=x

# %%
newlist8
# Out:
# ['location',
#  'hotel',
#  'good',
#  'everything',
#  'good',
#  'come',
#  'something',
#  'maybe',
#  'price',
#  'much',
#  'location',
#  'hotel',
#  'good',
#  'staff',
#  'friendly',
#  'kind',
#  'always',
#  'ready',
#  'help',
#  'really',
#  'nice',
#  'view',
#  'tiny',
#  'touch',
#  'glamour',
#  'worked',
#  'well',
#  'comfty',
#  'great',
#  'location',
#  'furniture',
#  'breakfast',
#  'fulfilling',
#  'different',
#  'taste',
#  'people',
#  'making',
#  'room',
#  'organized',
#  'much',
#  'maintenance',
#  'working',
#  'night',
#  'hour',
#  'ant',
#  'great',
#  'location',
#  'amazing',
#  'view',
#  'twin',
#  'tower',
#  'nice',
#  'could',
#  'better',
#  'maintenance',
#  'place',
#  'stringent',
#  'fixture',
#  'could',
#  'round',
#  'repair',
#  'overhaul',
#  'minor',
#  'problem',
#  'stay',
#  'pleasant',
#  'always',
#  'wanted',
#  'stay',
#  'hotel',
#  'completed',
#  'stay',
#  'breakfast',
#  'good',
#  'however',
#  'better',
#  'spread',
# ...

# %%
stem_original=review_h['rev_stop_tree']
from nltk.probability import FreqDist
newlist9=[]
fd_words = FreqDist(newlist9)
for x in stem_original:
    newlist9+=x

# %%
compare_stem = pd.DataFrame(newlist9)

# %%
compare_stem.columns = ['stem_original']

# %%
compare_stem['stem_porter'] = newlist5
compare_stem['stem_lan'] = newlist6
compare_stem['stem_snow'] = newlist7
compare_stem['stem_lemma'] = newlist8

# %%
compare_stem.to_csv("stemming.csv", index=False, encoding='utf8')

# %%
remove_single = ['e', 'u', 'n','also','get','got','go','could','nan']
review_h['lemma']=review_h['lemma'].apply(lambda x: [item for item in x if item not in remove_single])

# %%
stem_lemma=review_h['lemma']
from nltk.probability import FreqDist
newlist10=[]
fd_words = FreqDist(newlist10)
for x in stem_lemma:
    newlist10+=x

# %%
# initializing a dictionary
d = {};

# counting number of times each word comes up in list of words
for key in newlist10: 
    d[key] = d.get(key, 0) + 1

word_count=sorted(d.items(), key = lambda x: x[1], reverse = True)

# %%
print(word_count)
# Out:
# [('hotel', 5436), ('room', 5248), ('staff', 2826), ('view', 2673), ('great', 2588), ('stay', 2228), ('service', 2083), ('good', 1959), ('hyatt', 1951), ('grand', 1803), ('location', 1712), ('breakfast', 1686), ('tower', 1595), ('floor', 1394), ('excellent', 1272), ('nice', 1167), ('food', 1123), ('best', 1107), ('amazing', 986), ('time', 983), ('pool', 959), ('well', 953), ('check', 910), ('friendly', 908), ('lobby', 868), ('would', 863), ('klcc', 853), ('club', 852), ('stayed', 819), ('restaurant', 792), ('night', 790), ('really', 744), ('petronas', 736), ('experience', 714), ('twin', 701), ('city', 643), ('everything', 621), ('area', 619), ('helpful', 607), ('kuala', 596), ('lounge', 589), ('clean', 586), ('like', 585), ('back', 581), ('comfortable', 575), ('lumpur', 575), ('perfect', 533), ('fantastic', 517), ('place', 510), ('spacious', 510), ('need', 462), ('guest', 459), ('make', 457), ('walk', 453), ('shopping', 451), ('lift', 440), ('always', 419), ('facility', 418), ('star',
# ...

# %%
df_word = pd.DataFrame(word_count)

# %%
df_word.columns = ['freq_word', 'tot_word']

# %%
from nltk.tag import pos_tag

# %%
df_word['word_pos_tagging']=nltk.tag.pos_tag(df_word['freq_word'])
df_word.head()
# Out:
#   freq_word  tot_word word_pos_tagging
# 0     hotel      5436      (hotel, NN)
# 1      room      5248       (room, NN)
# 2     staff      2826      (staff, NN)
# 3      view      2673       (view, NN)
# 4     great      2588      (great, JJ)

# %%
df_word.to_csv("word_count.csv", index=False, encoding='utf8')

# %%
tagg=nltk.tag.pos_tag(df_word['freq_word'])

# %%
word_tagg = pd.DataFrame(tagg)

# %%
word_tagg.columns = ['freq_word', 'word_tag']
word_tagg.head()
# Out:
#   freq_word word_tag
# 0     hotel       NN
# 1      room       NN
# 2     staff       NN
# 3      view       NN
# 4     great       JJ

# %%
review_h['n-gram2'] = review_h['lemma'].apply(lambda row: list(nltk.ngrams(row, 2)))
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       the location of this hotel is very good.
# 1    7.1                                great location.
# 2    9.2                       nice but could be better
# 3    6.7       the hotel is clean & the view is amazing
# 4     10   excellent location with very friendly staff.
#
#                                               review  \
# 0   everything was good. if we have to come up wi...
# 1   old furniture. breakfast was not fulfilling f...
# 2   the maintenance of the place should be a bit ...
# 3   i stayed in twin bedroom. it suits for couple...
# 4   the lifts are a little confusing at first and...
#
#                                           review_com  \
# 0    location  this hotel  very good   everything...
# 1   great location    furniture  breakfast   fulf...
# 2   nice  could  better   maintenance   place sho...
# 3    hotel  clean    view  amazing   stayed  twin...
# ...

# %%
review_h['n-gram'] = review_h['lemma'].apply(lambda row: list(nltk.ngrams(row, 3)))
review_h.head()
# Out:
#   rating                                          title  \
# 0    8.3       the location of this hotel is very good.
# 1    7.1                                great location.
# 2    9.2                       nice but could be better
# 3    6.7       the hotel is clean & the view is amazing
# 4     10   excellent location with very friendly staff.
#
#                                               review  \
# 0   everything was good. if we have to come up wi...
# 1   old furniture. breakfast was not fulfilling f...
# 2   the maintenance of the place should be a bit ...
# 3   i stayed in twin bedroom. it suits for couple...
# 4   the lifts are a little confusing at first and...
#
#                                           review_com  \
# 0    location  this hotel  very good   everything...
# 1   great location    furniture  breakfast   fulf...
# 2   nice  could  better   maintenance   place sho...
# 3    hotel  clean    view  amazing   stayed  twin...
# ...

# %%
n_gram2=review_h['n-gram2']
from nltk.probability import FreqDist
newlist12=[]
fd_words = FreqDist(newlist12)
for x in n_gram2:
    newlist12+=x

# %%
sep = [map(str,l) for l in newlist12]

newlist12 = [str(' '.join(s)) for s in sep]

# %%
newlist12
# Out:
# ['location hotel',
#  'hotel good',
#  'good everything',
#  'everything good',
#  'good come',
#  'come something',
#  'something maybe',
#  'maybe price',
#  'price much',
#  'much location',
#  'location hotel',
#  'hotel good',
#  'good staff',
#  'staff friendly',
#  'friendly kind',
#  'kind always',
#  'always ready',
#  'ready help',
#  'help really',
#  'really nice',
#  'nice view',
#  'view tiny',
#  'tiny touch',
#  'touch glamour',
#  'glamour worked',
#  'worked well',
#  'well comfty',
#  'great location',
#  'location furniture',
#  'furniture breakfast',
#  'breakfast fulfilling',
#  'fulfilling different',
#  'different taste',
#  'taste people',
#  'people making',
#  'making room',
#  'room organized',
#  'organized much',
#  'much maintenance',
#  'maintenance working',
#  'working night',
#  'night hour',
#  'hour ant',
#  'ant great',
#  'great location',
#  'location amazing',
#  'amazing view',
#  'view twin',
#  'twin tower',
#  'nice better',
# ...

# %%
# initializing a dictionary
d = {};

# counting number of times each word comes up in list of words
for key in newlist12: 
    d[key] = d.get(key, 0) + 1

bigram=sorted(d.items(), key = lambda x: x[1], reverse = True)

# %%
bigram
# Out:
# [('grand hyatt', 1383),
#  ('twin tower', 644),
#  ('kuala lumpur', 573),
#  ('petronas tower', 551),
#  ('club lounge', 345),
#  ('best hotel', 296),
#  ('view petronas', 291),
#  ('great location', 283),
#  ('staff friendly', 273),
#  ('great view', 265),
#  ('view room', 258),
#  ('stay grand', 257),
#  ('tower view', 250),
#  ('hyatt kuala', 240),
#  ('walking distance', 236),
#  ('great hotel', 210),
#  ('star hotel', 207),
#  ('room spacious', 203),
#  ('ground floor', 197),
#  ('hotel staff', 193),
#  ('breakfast buffet', 190),
#  ('friendly helpful', 181),
#  ('grand club', 181),
#  ('hotel room', 180),
#  ('good location', 180),
#  ('hotel great', 174),
#  ('room service', 171),
#  ('view twin', 168),
#  ('come back', 166),
#  ('friendly staff', 161),
#  ('38th floor', 159),
#  ('amazing view', 158),
#  ('stayed night', 155),
#  ('swimming pool', 149),
#  ('room view', 148),
#  ('excellent service', 148),
#  ('club room', 148),
#  ('customer service', 146),
# ...

# %%
bigram_word = pd.DataFrame(bigram)

# %%
bigram_word.columns = ['freq_word', 'tot_word']

# %%
bigram_word.to_csv("bigram_word.csv", index=False, encoding='utf8')

# %%
n_gram=review_h['n-gram']
from nltk.probability import FreqDist
newlist11=[]
fd_words = FreqDist(newlist11)
for x in n_gram:
    newlist11+=x

# %%
sep = [map(str,l) for l in newlist11]

newlist11 = [str(' '.join(s)) for s in sep]

# %%
newlist11
# Out:
# ['location hotel good',
#  'hotel good everything',
#  'good everything good',
#  'everything good come',
#  'good come something',
#  'come something maybe',
#  'something maybe price',
#  'maybe price much',
#  'price much location',
#  'much location hotel',
#  'location hotel good',
#  'hotel good staff',
#  'good staff friendly',
#  'staff friendly kind',
#  'friendly kind always',
#  'kind always ready',
#  'always ready help',
#  'ready help really',
#  'help really nice',
#  'really nice view',
#  'nice view tiny',
#  'view tiny touch',
#  'tiny touch glamour',
#  'touch glamour worked',
#  'glamour worked well',
#  'worked well comfty',
#  'great location furniture',
#  'location furniture breakfast',
#  'furniture breakfast fulfilling',
#  'breakfast fulfilling different',
#  'fulfilling different taste',
#  'different taste people',
#  'taste people making',
#  'people making room',
#  'making room organized',
#  'room organized much',
#  'organized much maintenance',
# ...

# %%
# initializing a dictionary
d = {};

# counting number of times each word comes up in list of words
for key in newlist11: 
    d[key] = d.get(key, 0) + 1

trigram=sorted(d.items(), key = lambda x: x[1], reverse = True)

# %%
trigram
# Out:
# [('stay grand hyatt', 244),
#  ('hyatt kuala lumpur', 237),
#  ('grand hyatt kuala', 226),
#  ('view petronas tower', 225),
#  ('view twin tower', 162),
#  ('twin tower view', 126),
#  ('petronas twin tower', 124),
#  ('staff friendly helpful', 94),
#  ('stayed grand hyatt', 78),
#  ('tower view room', 75),
#  ('grand hyatt hotel', 72),
#  ('within walking distance', 67),
#  ('hotel kuala lumpur', 62),
#  ('floor ceiling window', 61),
#  ('hotel great location', 57),
#  ('grand club lounge', 54),
#  ('walking distance klcc', 53),
#  ('best hotel ever', 49),
#  ('view petronas twin', 47),
#  ('definitely come back', 46),
#  ('staying grand hyatt', 43),
#  ('would highly recommend', 43),
#  ('highly recommend hotel', 43),
#  ('lobby 39th floor', 42),
#  ('twin tower room', 39),
#  ('lobby 38th floor', 38),
#  ('grand hyatt best', 37),
#  ('best hotel stayed', 37),
#  ('night grand hyatt', 35),
#  ('hotel ever stayed', 34),
#  ('hotel grand hyatt', 34),
# ...

# %%
trigram_word = pd.DataFrame(trigram)

# %%
trigram_word.columns = ['freq_word', 'tot_word']

# %%
trigram_word.to_csv("trigram_word.csv", index=False, encoding='utf8')

# %%
bigrams = nltk.collocations.BigramAssocMeasures()
trigrams = nltk.collocations.TrigramAssocMeasures()

# %%
bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(newlist10)
trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(newlist10)

# %%
#bigrams
bigram_freq = bigramFinder.ngram_fd.items()
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)
#trigrams
trigram_freq = trigramFinder.ngram_fd.items()
trigramFreqTable = pd.DataFrame(list(trigram_freq), columns=['trigram','freq']).sort_values(by='freq', ascending=False)

# %%
#function to filter for ADJ/NN bigrams
def rightTypes(ngram):
    acceptable_types = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    second_type = ('NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in acceptable_types and tags[1][1] in second_type:
        return True
    else:
        return False
#function to filter for trigrams
def rightTypesTri(ngram):
    first_type = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    third_type = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in first_type and tags[2][1] in third_type:
        return True
    else:
        return False#filter trigrams

# %%
#filter bigrams
filtered_bi = bigramFreqTable[bigramFreqTable.bigram.map(lambda x: rightTypes(x))]

# %%
filtered_bi.head()
# Out:
#                  bigram  freq
# 205      (grand, hyatt)  1383
# 46        (twin, tower)   644
# 560     (kuala, lumpur)   573
# 857   (petronas, tower)   551
# 1466     (club, lounge)   345

# %%
filtered_bi.to_csv("filter_bigram_word.csv", index=False, encoding='utf8')

# %%
filtered_tri = trigramFreqTable[trigramFreqTable.trigram.map(lambda x: rightTypesTri(x))]
filtered_tri.head()
# Out:
#                      trigram  freq
# 582     (stay, grand, hyatt)   247
# 594   (hyatt, kuala, lumpur)   237
# 593    (grand, hyatt, kuala)   226
# 929  (view, petronas, tower)   225
# 47       (view, twin, tower)   162

# %%
filtered_tri.to_csv("filter_trigram_word.csv", index=False, encoding='utf8')
